# %%
import pandas as pd
df = pd.read_csv('socialMedia.csv')
df
# Out:
#       Platform PostType                                       Post Content  \
# 0     LinkedIn    Video         Section admit on time section mission key.
# 1     LinkedIn    Image    Option resource street may north just economic.
# 2      Twitter     Link               Daughter reflect significant finish.
# 3     LinkedIn    Video              Them accept again physical poor wish.
# 4    Instagram    Video  Think way star question cold century general c...
# ..         ...      ...                                                ...
# 622  Instagram     Link  Responsibility trade morning interest require ...
# 623   Facebook    Video       Account believe recently industry wish know.
# 624  Instagram    Video              Boy walk so half size thought reveal.
# 625    Twitter    Video      Meeting sit early drive dog room mean decade.
# 626  Instagram    Image     Table ok whole management respond family fear.
#
# ...

# %%
df = df[['Date', 'Likes']]
df.groupby('Date').mean().to_csv('socialMediaTime.csv')
